# %%
from khovanov import *
from knot_graphs import *
import networkx as nx

# %% [markdown]
# # TODO: fix edges

# %%
# 6_1
K = Link([(9, 4, 10, 5), (5, 8, 6, 9), (11, 2, 12, 3), (3, 10, 4, 11), (1, 7, 2, 6), (7, 1, 8, 12)])
G = adjacency_graph(K)

# %%
draw_adjacency_graph(K)

# %%
list(G.edges(keys=True, data=True))
# Out:
# [(0, 1, 0, {'head_strand': 3, 'tail_strand': 0, 'rad': 0.15}),
#  (0, 1, 1, {'head_strand': 0, 'tail_strand': 3, 'rad': -0.15}),
#  (0, 3, 0, {'head_strand': 2, 'tail_strand': 1, 'rad': 0.15}),
#  (0, 3, 1, {'head_strand': 1, 'tail_strand': 2, 'rad': -0.15}),
#  (1, 5, 0, {'head_strand': 2, 'tail_strand': 1, 'rad': 0}),
#  (1, 4, 0, {'head_strand': 3, 'tail_strand': 2, 'rad': 0}),
#  (2, 3, 0, {'head_strand': 3, 'tail_strand': 0, 'rad': 0.15}),
#  (2, 3, 1, {'head_strand': 0, 'tail_strand': 3, 'rad': -0.15}),
#  (2, 4, 0, {'head_strand': 2, 'tail_strand': 1, 'rad': 0}),
#  (2, 5, 0, {'head_strand': 3, 'tail_strand': 2, 'rad': 0}),
#  (4, 5, 0, {'head_strand': 1, 'tail_strand': 0, 'rad': 0.15}),
#  (4, 5, 1, {'head_strand': 0, 'tail_strand': 1, 'rad': -0.15})]
